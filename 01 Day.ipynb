# %% [markdown]
# # Variable

# %%
name = "Anush"         #A variable is a named container that stores data in memory.

# %%
1name = "Anush"        # Must start with a letter or underscore not a digit.
# Out:
#   Cell In[96], line 1
#     1name = "Anush"        # Must start with a letter or underscore (_) not a digit.
#     ^
# SyntaxError: invalid decimal literal

# %%
name 1 = "tushar"
# Out:
#   Cell In[97], line 1
#     name 1 = "tushar"
#          ^
# SyntaxError: invalid syntax

# %%
name_1 = "tushar"

# %%
_name = "sanket"

# %%
@name = "pranay"
# Out:
#   Cell In[100], line 1
#     @name = "pranay"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name_ = "Ketan"

# %%
a = 10

# %%
a
# Out:
# 10

# %%
b = 50

# %%
b
# Out:
# 50

# %%
a,b,c = 10,20,30

# %%
c
# Out:
# 30

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
a,b,c
# Out:
# (10, 20, 30)

# %%
a,b,c = 10,20,30,40
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 a,b,c = 10,20,30,40
#
# ValueError: too many values to unpack (expected 3)

# %%
name = "Anush"

# %%
name
# Out:
# 'Anush'

# %%
print(name)
# Out:
# Anush

# %%
1name = 4          #A variable name should never start with a number or special symbols
# Out:
#   Cell In[79], line 1
#     1name = 4
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # Data Type

# %% [raw]
# int       =  1,2,3,4,5,6,7,8,9       # only whole numbers
# float     = 1.99                     # decimal numbers
# str       = "Hello ", "Anush"
# bool      = True/False
# complex   = x = 56 + 7j

# %%
a = 10
b = 50.99
c = "Anush"
d = True
e = x = 56 + 7j

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# bool

# %%
type(e)
# Out:
# complex

# %%
a = 10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
b = 5.999

# %%
b
# Out:
# 5.999

# %%
type(b)
# Out:
# float

# %%
c = "Sanket"

# %%
c
# Out:
# 'Sanket'

# %%
type(c)
# Out:
# str

# %%
d = True

# %%
d
# Out:
# True

# %%
type(d)
# Out:
# bool

# %%
e = 56 + 8j

# %%
e
# Out:
# (56+8j)

# %%
type (e)
# Out:
# complex

# %% [markdown]
# # Data structure

# %%
list    =  [1,2,3,4]
tuple   =  (1,2,3,4)
set     =  {1,2,3,4}
dict    =  {1:"jan", 2:"feb", 3:"march",}

# %%
name1 = [100]

# %%
type(name1)
# Out:
# list

# %%
name2 = (200,300,400)

# %%
type(name2)
# Out:
# tuple

# %%
prank = {1,2,3,4}

# %%
type(prank)
# Out:
# set

# %%
lisa = {1:"jan", 2:"feb", 3:"march",}

# %%
type(lisa)
# Out:
# dict

# %% [markdown]
# # iterable --- non -iterable

# %% [raw]
# # non iterable
#
# int
# float
# bool
# complex
# None

# %% [raw]
# # iterable
#
# str
# list
# tuple
# set
# dict
# range
