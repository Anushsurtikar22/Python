# %% [markdown]
# # Arithmetic operators

# %%
a = 5
b = 7
c = 2
d = 6

# %%
a + d
# Out:
# 11

# %%
c + b
# Out:
# 9

# %%
b - a
# Out:
# 2

# %%
c - d
# Out:
# -4

# %%
d - c
# Out:
# 4

# %%
a * c
# Out:
# 10

# %%
d * a
# Out:
# 30

# %%
b * c
# Out:
# 14

# %%
c / b
# Out:
# 0.2857142857142857

# %%
b / c
# Out:
# 3.5

# %%
b // c
# Out:
# 3

# %%
a // c
# Out:
# 2

# %%
a / c
# Out:
# 2.5

# %%
d % a
# Out:
# 1

# %%
b % c
# Out:
# 1

# %%
b % a
# Out:
# 2

# %%
a ** c
# Out:
# 25

# %%
c ** a
# Out:
# 32

# %% [markdown]
# # Comparison Operators

# %%
a
# Out:
# 5

# %%
b
# Out:
# 7

# %%
c
# Out:
# 2

# %%
d
# Out:
# 6

# %%
a < b
# Out:
# True

# %%
c > a
# Out:
# False

# %%
a > c
# Out:
# True

# %%
d == b
# Out:
# False

# %%
b == b
# Out:
# True

# %%
8 > 9
# Out:
# False

# %%
84 < 85
# Out:
# True

# %%
12 != 10
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
6 <= 7
# Out:
# True

# %%
6 <= 6
# Out:
# True

# %%
8 <= 7
# Out:
# False

# %%
6 >= 4
# Out:
# True

# %%
4 >= 4
# Out:
# True

# %%
5 >= 6
# Out:
# False

# %%
7 >= 8
# Out:
# False

# %% [markdown]
# # Logical Operators

# %%
5 > 6 and 5<6
# Out:
# False

# %%
2 < 6 and 5 > 3 or 5<9
# Out:
# True

# %%
5 != 10 and 5< 9
# Out:
# True

# %%
8 != 10 and 5 < 10
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
not False and True
# Out:
# True

# %%
not True or False
# Out:
# False

# %%
not False or True
# Out:
# True

# %%
not False or False
# Out:
# True

# %% [markdown]
# # Typecasting

# %%
a = "568"
b = 8767
c = 12.99

# %%
b
# Out:
# 8767

# %%
b = 8767

# %%
d = float(b)

# %%
d
# Out:
# 8767.0

# %%
l1 = str(b)

# %%
l1
# Out:
# '8767'

# %%
l2 = int(a)

# %%
l2
# Out:
# 568

# %%
l3 = int(b)

# %%
l3
# Out:
# 8767

# %%
l4 = int (c)

# %%
l4
# Out:
# 12
