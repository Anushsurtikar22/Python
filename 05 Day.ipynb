# %%
var = "anush"

# %%
var.removeprefix("n")
# Out:
# 'anush'

# %%
var.removeprefix("an")
# Out:
# 'ush'

# %%
var.removesuffix("s")
# Out:
# 'anush'

# %%
var.removesuffix("sh")
# Out:
# 'anu'

# %%
var.replace("a", "A")
# Out:
# 'Anush'

# %%
var.replace("", "A")
# Out:
# 'AaAnAuAsAhA'

# %%
name = "Anush  "

# %%
name
# Out:
# 'Anush  '

# %%
name.replace(" ", "hh")
# Out:
# 'Anushhhhh'

# %%
var1 = "first string"

# %%
var1.replace(" ", "--")
# Out:
# 'first--string'

# %%
var1.partition(" ")
# Out:
# ('first', ' ', 'string')

# %%
var1.split()
# Out:
# ['first', 'string']

# %%
var1
# Out:
# 'first string'

# %%
var1.split("i")
# Out:
# ['f', 'rst str', 'ng']

# %%
var1.rpartition("i")
# Out:
# ('first str', 'i', 'ng')

# %%
var2 = "      string^^^&&"

# %%
var2
# Out:
# '      string^^^&&'

# %%
var2.lstrip()
# Out:
# 'string^^^&&'

# %%
var2.rstrip("^&")
# Out:
# '      string'

# %%
var2 = var2.rstrip("^&")

# %%
var2
# Out:
# '      string'

# %%
var2=var2.lstrip()

# %%
var2
# Out:
# 'string'

# %%
l1 = "Dutch computer programmer"

# %%
l1.partition("computer")
# Out:
# ('Dutch ', 'computer', ' programmer')

# %%
l1.partition("ter")
# Out:
# ('Dutch compu', 'ter', ' programmer')

# %%
l1.split("computer")
# Out:
# ['Dutch ', ' programmer']

# %%
s1 = l1.split()

# %%
s1
# Out:
# ['Dutch', 'computer', 'programmer']

# %%
" ".join(s1)
# Out:
# 'Dutch computer programmer'

# %%
"--".join(s1)
# Out:
# 'Dutch--computer--programmer'

# %%
l1.replace("t", "T")
# Out:
# 'DuTch compuTer programmer'

# %%
l1.removeprefix("Dutch")
# Out:
# ' computer programmer'

# %%
l1.removesuffix("programmer")
# Out:
# 'Dutch computer '

# %% [markdown]
# ## Tuple

# %%
t1 = ()

# %%
type(t1)
# Out:
# tuple

# %%
t1 = ("red", "pink", "yellow", "orange", "white", "black")

# %%
t1
# Out:
# ('red', 'pink', 'yellow', 'orange', 'white', 'black')

# %%
t2 = ("blue", "purple", "grey")

# %%
t2
# Out:
# ('blue', 'purple', 'grey')

# %%
t1 + t2
# Out:
# ('red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey')

# %%
t1 + var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 t1 + var
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
t2 * 3
# Out:
# ('blue', 'purple', 'grey', 'blue', 'purple', 'grey', 'blue', 'purple', 'grey')

# %%
t1
# Out:
# ('red', 'pink', 'yellow', 'orange', 'white', 'black')

# %%
t1[4]
# Out:
# 'white'

# %%
t1[-2]
# Out:
# 'white'

# %%
t1[1]
# Out:
# 'pink'

# %%
t3 = t1 + t2

# %%
t3
# Out:
# ('red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey')

# %%
t3 [1:4]
# Out:
# ('pink', 'yellow', 'orange')

# %%
t3 [ : : -1]
# Out:
# ('grey', 'purple', 'blue', 'black', 'white', 'orange', 'yellow', 'pink', 'red')

# %%
t3[:2:]
# Out:
# ('red', 'pink')

# %%
t3[3:8:-1]
# Out:
# ()

# %%
t3[8:3:-1]
# Out:
# ('grey', 'purple', 'blue', 'black', 'white')

# %%
t3[7]
# Out:
# 'purple'

# %%
t3[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 t3[9]
#
# IndexError: tuple index out of range

# %%
t3[2:20]
# Out:
# ('yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey')

# %%
len(t3)
# Out:
# 9

# %%
t1
# Out:
# ('red', 'pink', 'yellow', 'orange', 'white', 'black')

# %%
t1[3]
# Out:
# 'orange'

# %%
t1[3] = "skyblue"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 t1[3] = "skyblue"
#
# TypeError: 'tuple' object does not support item assignment

# %%
"orange" in t2
# Out:
# False

# %%
"orange" in t1
# Out:
# True

# %%
t4 = t2 * 3

# %%
t4
# Out:
# ('blue', 'purple', 'grey', 'blue', 'purple', 'grey', 'blue', 'purple', 'grey')

# %%
t4.count("blue")
# Out:
# 3

# %%
t4.index("purple", 4)
# Out:
# 4

# %%
t4.index("purple", 5)
# Out:
# 7

# %% [markdown]
# ## List

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l1 = ['blue', 'purple', 'grey', 'yellow']

# %%
l2 = ['orange', 'white', 'black', 'red']

# %%
l1
# Out:
# ['blue', 'purple', 'grey', 'yellow']

# %%
l2
# Out:
# ['orange', 'white', 'black', 'red']

# %%
l1 + l2
# Out:
# ['blue', 'purple', 'grey', 'yellow', 'orange', 'white', 'black', 'red']

# %%
l2 * 3
# Out:
# ['orange',
#  'white',
#  'black',
#  'red',
#  'orange',
#  'white',
#  'black',
#  'red',
#  'orange',
#  'white',
#  'black',
#  'red']

# %%
l1[2]
# Out:
# 'grey'

# %%
l2[ 1]
# Out:
# 'white'

# %%
l1[::-1]
# Out:
# ['yellow', 'grey', 'purple', 'blue']

# %%
l2[::-1]
# Out:
# ['red', 'black', 'white', 'orange']

# %%
t2
# Out:
# ('blue', 'purple', 'grey')

# %%
l2
# Out:
# ['orange', 'white', 'black', 'red']

# %%
t2 + l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 t2 + l2
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
l1
# Out:
# ['blue', 'purple', 'grey', 'yellow']

# %%
l1[2] = "orange"

# %%
l1
# Out:
# ['blue', 'purple', 'orange', 'yellow']

# %%
lis = ["yellow", 22,2.8,True, ('blue', 'purple'), ['grey', 'yellow'],{'orange':'pink'}, {1:'white', 2:'black'}, None]

# %%
len(lis)
# Out:
# 9

# %%
lis[-2]
# Out:
# {1: 'white', 2: 'black'}

# %%
lis[3]
# Out:
# True

# %%
lis[5][0]
# Out:
# 'grey'

# %%
lis[0][-2]
# Out:
# 'o'

# %%
lis
# Out:
# ['yellow',
#  22,
#  2.8,
#  True,
#  ('blue', 'purple'),
#  ['grey', 'yellow'],
#  {'orange': 'pink'},
#  {1: 'white', 2: 'black'},
#  None]

# %%
lis[0][5]
# Out:
# 'w'

# %%
lis[8]

# %%
lis[7][1]
# Out:
# 'white'

# %%
tup = ('yellow',
 22,
 2.8,
 True,
 ('blue', 'purple'),
 ['grey', 'yellow'],
 {'orange': 'pink'},
 {1: 'white', 2: 'black'},
 None)

# %%
tup[4][1]
# Out:
# 'purple'

# %%
tup[6]
# Out:
# {'orange': 'pink'}

# %%
tup[6][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 tup[6][0]
#
# KeyError: 0

# %%
tup[6]['orange']
# Out:
# 'pink'

# %%
lis[0].upper()
# Out:
# 'YELLOW'

# %%
lis
# Out:
# ['yellow',
#  22,
#  2.8,
#  True,
#  ('blue', 'purple'),
#  ['grey', 'yellow'],
#  {'orange': 'pink'},
#  {1: 'white', 2: 'black'},
#  None]

# %%
lis[5].index("grey")
# Out:
# 0
