# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Dell\\Downloads\\22. messy_sales_data.csv")

# %%
sd = df.copy()

# %%
sd.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
sd.tail()
# Out:
#          OrderID CustomerID        CustomerName       City    Category  \
# 106570  ORD49057  CUST01636            MAX OM      chennai   FURNITURE
# 106571  ORD60012  CUST01826        CHARAN MANNE       pune        Toys
# 106572  ORD78050  CUST04033         Isaiah Wali      DELHI   Furniture
# 106573  ORD68225  CUST04602    Ladli Nazareth    AHMEDABAD  electronic
# 106574  ORD72531  CUST07969           Yatin Rao    Chennai       Sport
#
#              PaymentMode       Price  Quantity  DiscountPct  Rating  \
# 106570        debit card  Rs.1961.37       4.0            0     5.0
# 106571  Cash on Delivery  Rs.1468.22       2.0           20     3.3
# 106572        Debit Card      414.94       2.0           10     3.3
# 106573        DEBIT CARD      916.52       1.0           25     4.6
# 106574        DEBIT CARD      891.46       2.0            5     4.3
#
#           OrderDate  CustomerAge                    Email       Phone  \
# ...

# %%
sd.shape
# Out:
# (106575, 15)

# %%
sd.size
# Out:
# 1598625

# %%
sd.columns
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName', 'City', 'Category',
#        'PaymentMode', 'Price', 'Quantity', 'DiscountPct', 'Rating',
#        'OrderDate', 'CustomerAge', 'Email', 'Phone', 'ReviewText'],
#       dtype='object')

# %%
sd.dtypes
# Out:
# OrderID          object
# CustomerID       object
# CustomerName     object
# City             object
# Category         object
# PaymentMode      object
# Price            object
# Quantity        float64
# DiscountPct       int64
# Rating          float64
# OrderDate        object
# CustomerAge     float64
# Email            object
# Phone            object
# ReviewText       object
# dtype: object

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106575 entries, 0 to 106574
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   OrderID       106575 non-null  object
#  1   CustomerID    106575 non-null  object
#  2   CustomerName  106575 non-null  object
#  3   City          104481 non-null  object
#  4   Category      106575 non-null  object
#  5   PaymentMode   103332 non-null  object
#  6   Price         106575 non-null  object
#  7   Quantity      106575 non-null  float64
#  8   DiscountPct   106575 non-null  int64
#  9   Rating        100129 non-null  float64
#  10  OrderDate     102358 non-null  object
#  11  CustomerAge   106575 non-null  float64
#  12  Email         99176 non-null   object
#  13  Phone         98117 non-null   object
#  14  ReviewText    93200 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 12.2+ MB

# %%
sd.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City             2094
# Category            0
# PaymentMode      3243
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# dtype: int64

# %%
sd.isna().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City             2094
# Category            0
# PaymentMode      3243
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# dtype: int64

# %%
sd.isnull().sum().sum()
# Out:
# 45232

# %%
sd.describe()
# Out:
#             Quantity    DiscountPct         Rating    CustomerAge
# count  106575.000000  106575.000000  100129.000000  106575.000000
# mean        2.066817       9.382125       3.409874      39.678893
# std         1.387769       9.176865       1.306731      19.263288
# min        -5.000000       0.000000       0.500000       0.000000
# 25%         1.000000       0.000000       2.600000      28.000000
# 50%         2.000000      10.000000       3.300000      38.000000
# 75%         3.000000      20.000000       4.100000      47.000000
# max         5.000000      25.000000       9.900000     150.000000

# %%
sd.describe(include="all").T
# Out:
#                  count  unique                                       top  \
# OrderID         106575  105000                                  ORD17079
# CustomerID      106575    9000                                 CUST01057
# CustomerName    106575   37440                               Charvi Dara
# City            104481      56                                 hyderabad
# Category        106575      35                                    BEAUTY
# PaymentMode     103332      24                                       UPI
# Price           106575   88579                                    966.86
# Quantity      106575.0     NaN                                       NaN
# DiscountPct   106575.0     NaN                                       NaN
# Rating        100129.0     NaN                                       NaN
# OrderDate       102358    3367                                01/03/2024
# CustomerAge   106575.0     NaN                                       NaN
# ...

# %%
type(sd.City)
# Out:
# pandas.core.series.Series

# %%
sd.City
# Out:
# 0         bangalore
# 1             DELHI
# 2           chennai
# 3           Jaipur
# 4           Amdavad
#             ...
# 106570      chennai
# 106571         pune
# 106572        DELHI
# 106573    AHMEDABAD
# 106574      Chennai
# Name: City, Length: 106575, dtype: object

# %%
type(sd[["City", "Price", "Category"]])
# Out:
# pandas.core.frame.DataFrame

# %%
sd[["City", "Price", "Category"]]
# Out:
#              City       Price    Category
# 0       bangalore      904.48     Grocery
# 1           DELHI     1823.76      SPORTS
# 2         chennai      770.67  electronic
# 3         Jaipur      2028.06    Clothing
# 4         Amdavad      604.00   FURNITURE
# ...           ...         ...         ...
# 106570    chennai  Rs.1961.37   FURNITURE
# 106571       pune  Rs.1468.22        Toys
# 106572      DELHI      414.94   Furniture
# 106573  AHMEDABAD      916.52  electronic
# 106574    Chennai      891.46       Sport
#
# [106575 rows x 3 columns]

# %%
sd["City"].value_counts()
# Out:
# City
# hyderabad     2652
# Jaipur        2651
# JAIPUR        2635
# LUCKNOW       2634
# Jaipur        2631
#  Hyderabad    2628
#  Lucknow      2602
# Hyderabad     2585
# Lucknow       2575
# jaipur        2569
# HYDERABAD     2562
# lucknow       2547
# Ahmedabad     2134
# Poona         2129
# pune          2124
# Amdavad       2110
# Pune          2093
# PUNE          2086
# ahmedabad     2085
# amdavad       2082
# poona         2012
# AHMEDABAD     1994
# CALCUTTA      1833
# madras        1816
# Madras        1807
# chennai       1805
# Calcutta      1792
# Chennai       1791
# Kolkata       1755
# KOLKATA       1753
# kolkata       1739
# CHENNAI       1728
# calcutta      1672
# MADRAS        1663
# banglore      1557
# bangalore     1549
# New Delhi     1526
# Bangalore     1517
# NEW DELHI     1517
# bengaluru     1488
# BANGALORE     1481
# new delhi     1473
# Bengaluru     1462
# DELHI         1456
# delhi         1448
# Delhi         1444
# Banglore      1436
# ...

# %%
sd["Category"].nunique()
# Out:
# 35

# %%
sd["Category"].unique()
# Out:
# array(['Grocery', 'SPORTS', 'electronic', 'Clothing', 'FURNITURE',
#        'CLOTHING', 'BEAUTY', 'Furnitures', 'Clothings', 'electronics',
#        'Beauty', 'TOYS', 'sports', 'beauty', 'grocery', 'Book', 'Sports',
#        'Groceries', 'Electronics', 'book', 'Books', 'GROCERY',
#        'Clothing ', 'books', 'furniture', 'ELECTRONICS', 'Furniture',
#        'clothing', 'Toys', 'Electronic', 'toys', 'Toy', 'BOOKS', 'toy',
#        'Sport'], dtype=object)

# %%
sd["Category"].value_counts()
# Out:
# Category
# BEAUTY         4499
# Beauty         4429
# beauty         4380
# furniture      3464
# SPORTS         3401
# sports         3345
# GROCERY        3331
# FURNITURE      3314
# Furnitures     3312
# Grocery        3307
# Furniture      3303
# grocery        3299
# Sports         3294
# Groceries      3268
# Sport          3250
# electronic     2806
# toys           2802
# Toy            2747
# CLOTHING       2723
# ELECTRONICS    2712
# Clothings      2695
# Clothing       2695
# Book           2684
# BOOKS          2671
# Clothing       2670
# clothing       2657
# books          2656
# book           2655
# Electronic     2654
# TOYS           2646
# toy            2622
# Books          2590
# Electronics    2588
# electronics    2565
# Toys           2541
# Name: count, dtype: int64

# %%
sd.duplicated().sum()
# Out:
# 1056

# %%
sd.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
sd["total_sales"] = df['Rating']*df["Quantity"]

# %%
sd["col1"] = sd["PaymentMode"]

# %%
sd.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
sd.sample(5)
# Out:
#         OrderID CustomerID     CustomerName       City     Category  \
# 98658  ORD95654  CUST00593   Chandani Soman  NEW DELHI        Sport
# 39234  ORD82600  CUST06186        Yash Kibe   Banglore    Furniture
# 85749  ORD94152  CUST07905  Nilima Bhargava      poona        Books
# 46477   ORD1863  CUST00900    Isaiah Khosla        NaN  Electronics
# 70346  ORD64700  CUST04951    Nidra Chhabra    lucknow      grocery
#
#        PaymentMode      Price  Quantity  DiscountPct  Rating    OrderDate  \
# 98658   debit card  ₹1,168.64       4.0           20     3.3  15 Sep 2024
# 39234  credit_card     192.72       1.0           10     4.2   13-09-2023
# 85749          cod    3195.45       1.0           20     1.2   04/03/2024
# 46477           DC   -1108.24       4.0            0     4.0   03/11/2024
# 70346  net_banking     896.51       2.0           20     3.4   04/20/2024
#
#        CustomerAge                       Email           Phone  \
# ...

# %%
sd.drop("col1", axis = 1)
# Out:
#          OrderID CustomerID          CustomerName       City    Category  \
# 0       ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1       ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2       ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3       ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4       ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
# ...          ...        ...                   ...        ...         ...
# 106570  ORD49057  CUST01636              MAX OM      chennai   FURNITURE
# 106571  ORD60012  CUST01826          CHARAN MANNE       pune        Toys
# 106572  ORD78050  CUST04033           Isaiah Wali      DELHI   Furniture
# 106573  ORD68225  CUST04602      Ladli Nazareth    AHMEDABAD  electronic
# 106574  ORD72531  CUST07969             Yatin Rao    Chennai       Sport
#
#              PaymentMode       Price  Quantity  DiscountPct  Rating  \
# ...

# %%
sd.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
df1 = sd.drop("col1", axis = 1)

# %%
df1.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
df.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3  ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
#
#    PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0  net_banking   904.48       3.0           10     3.3   2023-04-24
# 1  Net Banking  1823.76       4.0           20     5.0   04-01-2023
# 2          Upi   770.67       1.0            0     4.9   11/17/2024
# 3          COD  2028.06       1.0            0     2.9          NaN
# 4           cc   604.00       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# ...

# %%
df.drop("col1", axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.drop("col1", axis = 1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4784         obj = self
#    4785
#    4786         for axis, labels in axes.items():
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of          OrderID CustomerID          CustomerName       City    Category  \
# 0       ORD51058  CUST04879        Chaitanya Mane  bangalore     Grocery
# 1       ORD70248  CUST00177         Siddharth Sha      DELHI      SPORTS
# 2       ORD43804  CUST04537  Nathaniel Chatterjee    chennai  electronic
# 3       ORD46367  CUST07605     pranit contractor    Jaipur     Clothing
# 4       ORD32922  CUST03180    Hemang Chakraborty    Amdavad   FURNITURE
# ...          ...        ...                   ...        ...         ...
# 106570  ORD49057  CUST01636              MAX OM      chennai   FURNITURE
# 106571  ORD60012  CUST01826          CHARAN MANNE       pune        Toys
# 106572  ORD78050  CUST04033           Isaiah Wali      DELHI   Furniture
# 106573  ORD68225  CUST04602      Ladli Nazareth    AHMEDABAD  electronic
# 106574  ORD72531  CUST07969             Yatin Rao    Chennai       Sport
#
# ...
