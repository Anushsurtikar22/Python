# %% [markdown]
# # Conditions

# %%
if
elif
else

# %%
num = int(input())

if num > 10 :
    print("if block")

else:
    print("else block")
# Out:
#  11
# if block

# %%
num = int(input())

if num > 10 :
    print("if block")

else:
    print("else block")
# Out:
#  1
# else block

# %%
num = int(input())

if num >= 10 :
    print("if block")

elif num == 20:
    print("elif block")

else:
    print("else block")
# Out:
#  10
# if block

# %%
num = int(input())

if num >= 10 :
    print("if block")

elif num == 20:
    print("elif block")

else:
    print("else block")
# Out:
#  9
# else block

# %%
number = 10
A = 10
B = 20
C = 30

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
elif C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# python-1

# %%
number = 10
A = 10
B = 20
C = 30

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
if C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# python-1
# python-3

# %%
number = 30
A = 10
B = 20
C = 30

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
if C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# python-2
# python-3

# %%
number = 9
A = 10
B = 20
C = 0

if number == A:
    print("python-1")
elif number > B :
    print("python-2")
if C > B:
    print("python-3")
else:
    print("i don't know")
# Out:
# i don't know

# %%
number  = 10

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number < 11:
    print("number is less than 11")
# Out:
# number is less than 11

# %%
number  = 11

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number < 11:
    print("number is less than 11")
# Out:
# number is equal

# %%
number  = 12

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number < 11:
    print("number is less than 11")
# Out:
# number is greater than 11

# %%
number  = 11

if number == 11:
    print("number is equal")
elif number > 11:
    print("number is greater than 11")
    
if number == 11:
    print("number is less than 11")

if number == 11:
    print("   ---")
# Out:
# number is equal
# number is less than 11
#    ---

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  87
# You got distinction!

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  0
# Sorry you failed!

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  36
# You passed in second class

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  62
# You passed in first class

# %%
mark = int(input("Enter the mark "))

if mark < 0 or mark > 100: 
    print("Invalid marks are entered!")
    
elif mark >= 0 and mark < 35 :
    print("Sorry you failed!")
    
elif mark >= 36 and mark <= 60:
    print("You passed in second class")
    
elif mark >= 61 and mark <= 80 :
    print("You passed in first class")
    
elif mark >= 91 and mark <= 100:
    print("you are in top 10 list")
    
else :
    print("You got distinction!")
# Out:
# Enter the mark  95
# you are in top 10 list

# %%
number1 = int(input("Enter first number \n"))
number2 = int(input("Enter second number \n"))

if number1 == number2:
    print("Both numbers are same")
else:
    if number1 > number2:
        print("First number is bigger than second")
    else:
        print("First number is smaller than second")
# Out:
# Enter first number
#  10
# Enter second number
#  5
# First number is bigger than second

# %%
number1 = int(input("Enter first number \n"))
number2 = int(input("Enter second number \n"))

if number1 == number2:
    print("Both numbers are same")
else:
    if number1 > number2:
        print("First number is bigger than second")
    else:
        print("First number is smaller than second")
# Out:
# Enter first number
#  11
# Enter second number
#  15
# First number is smaller than second

# %%
number1 = int(input("Enter first number \n"))
number2 = int(input("Enter second number \n"))

if number1 == number2:
    print("Both numbers are same")
else:
    if number1 > number2:
        print("First number is bigger than second")
    else:
        print("First number is smaller than second")
# Out:
# Enter first number
#  10
# Enter second number
#  10
# Both numbers are same

# %%
number = int(input("Enter the number "))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number") 
else :
    print(number ," is odd number")
# Out:
# Enter the number  5
# 5  is odd number

# %%
number = int(input("Enter the number "))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number") 
else :
    print(number ," is odd number")
# Out:
# Enter the number  16
# 16  is even number

# %%
number = int(input("Enter the number "))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number") 
else :
    print(number ," is odd number")
# Out:
# Enter the number  7
# 7  is odd number

# %%
number = int(input("Enter the number "))

if number % 2 == 0 :   # if entered number is even then only message is shown to the user
    print(number ," is even number") 
else :
    print(number ," is odd number")
# Out:
# Enter the number  43
# 43  is odd number

# %%
length_in_cm = input("Enter the lenght in centimeter ")

length_in_cm = float(length_in_cm)
    
if length_in_cm < 0 :
    print("You have entered negative value. ")
else:
    length_in_inches = length_in_cm / 2.54
    print(length_in_cm, " cm = ", length_in_inches, " inches")
# Out:
# Enter the lenght in centimeter  -1
# You have entered negative value.

# %%
length_in_cm = input("Enter the lenght in centimeter ")

length_in_cm = float(length_in_cm)
    
if length_in_cm < 0 :
    print("You have entered negative value. ")
else:
    length_in_inches = length_in_cm / 2.54
    print(length_in_cm, " cm = ", length_in_inches, " inches")
# Out:
# Enter the lenght in centimeter  0
# 0.0  cm =  0.0  inches

# %%
length_in_cm = input("Enter the lenght in centimeter ")

length_in_cm = float(length_in_cm)
    
if length_in_cm < 0 :
    print("You have entered negative value. ")
else:
    length_in_inches = length_in_cm / 2.54
    print(length_in_cm, " cm = ", length_in_inches, " inches")
# Out:
# Enter the lenght in centimeter  2.54
# 2.54  cm =  1.0  inches

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  guest
# Enter your password:  password
# Incorrect password. Please try again.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  admin
# Enter your password:  password
# Login successful! Welcome, admin.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  admin
# Enter your password:  Anush22
# Incorrect password. Please try again.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  Anush
# Enter your password:  12345
# Unknown user. Please try again.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  admin
# Enter your password:  123456
# Incorrect password. Please try again.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  admin
# Enter your password:  12345
# Weak password. Please reset your password.

# %%
# Password and Username Checking
username = input("Enter your username: ")
password = input("Enter your password: ")


if username == "admin":
    if password == "password":
        print("Login successful! Welcome, admin.")
    elif password == "12345":
        print("Weak password. Please reset your password.")
    else:
        print("Incorrect password. Please try again.")
else:
    if username == "guest":
        if password == "guest":
            print("Login successful! Welcome, guest.")
        else:
            print("Incorrect password. Please try again.")
    else:
        print("Unknown user. Please try again.")
# Out:
# Enter your username:  guest
# Enter your password:  guest
# Login successful! Welcome, guest.

# %% [markdown]
# ## ternary operators

# %%
num = int(input())

if num%2 == 0:
    print("even")
else:
    print("odd")
# Out:
#  59
# odd

# %%
num = int(input())

if num%2 == 0:
    print("even")
else:
    print("odd")
# Out:
#  54
# even

# %%
"even" if num % 2 == 0 else "odd"
# Out:
# 'even'

# %%
"even" if num%3 ==0 else "odd"
# Out:
# 'even'

# %% [raw]
# print()  if condition  else print()

# %%
a, b, c = 10, 20, 30

# %%
"if block" if a > b "elif block" elif c == a

# %%
username = "admin"
password = "12345"

# %%
"correct" if username == "admin"  else  "password correct" if password == "12345" else "incorrect password"
# Out:
# 'correct'

# %%
if username == "admin":
    print("correct")
else:
    if password == "12345":
        print("correct password")
    else:
        print("incorrect password")
# Out:
# correct

# %%
price  = int(input())

if price  < 500 :
    print("i will be able to buy something")
    print()
    if price < 400 :
        print("i will be able to buy a jacket")
    elif price <= 300 :
        print("i will be able to buy a shirt")
    if price < 200 :
        print("i would like to do something")
    else :
        print("i wont be able to buy anyting")
else :
     print("i wont be able to buy anything with this price tag")
# Out:
#  499
# i will be able to buy something
#
# i wont be able to buy anyting

# %%
price  = int(input())

if price  < 500 :
    print("i will be able to buy something")
    print()
    if price < 400 :
        print("i will be able to buy a jacket")
    elif price <= 300 :
        print("i will be able to buy a shirt")
    if price < 200 :
        print("i would like to do something")
    else :
        print("i wont be able to buy anyting")
else :
     print("i wont be able to buy anything with this price tag")
# Out:
#  350
# i will be able to buy something
#
# i will be able to buy a jacket
# i wont be able to buy anyting

# %%
price  = int(input())

if price  < 500 :
    print("i will be able to buy something")
    print()
    if price < 400 :
        print("i will be able to buy a jacket")
    elif price <= 300 :
        print("i will be able to buy a shirt")
    if price < 200 :
        print("i would like to do something")
    else :
        print("i wont be able to buy anyting")
else :
     print("i wont be able to buy anything with this price tag")
# Out:
#  189
# i will be able to buy something
#
# i will be able to buy a jacket
# i would like to do something

# %%
price  = int(input())

if price  < 500 :
    print("i will be able to buy something")
    print()
    if price < 400 :
        print("i will be able to buy a jacket")
    elif price <= 300 :
        print("i will be able to buy a shirt")
    if price < 200 :
        print("i would like to do something")
    else :
        print("i wont be able to buy anyting")
else :
     print("i wont be able to buy anything with this price tag")
# Out:
#  501
# i wont be able to buy anything with this price tag

# %%
num = -49

if num > 50:
    print("if block")
elif num < 50:
    print("1st elif block")
elif num == 50:
    print("2nd elif block")
else:
    print("else block")
# Out:
# 1st elif block

# %%
num = 51

if num > 50:
    print("if block")
elif num < 50:
    print("1st elif block")
elif num == 50:
    print("2nd elif block")
else:
    print("else block")
# Out:
# if block

# %%
num = 50

if num > 50:
    print("if block")
elif num < 50:
    print("1st elif block")
elif num == 50:
    print("2nd elif block")
else:
    print("else block")
# Out:
# 2nd elif block
