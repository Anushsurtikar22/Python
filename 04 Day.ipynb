# %%
print("hello world")
# Out:
# hello world

# %%
print("hello \nworld")
# Out:
# hello
# world

# %%
print("hello \tworld")
# Out:
# hello 	world

# %%
s1 = "The mission of the Python Software Foundation is to promote, 
protect, and advance the Python programming language, 
and to support and facilitate the growth of a diverse and international"
# Out:
#   Cell In[5], line 1
#     s1 = "The mission of the Python Software Foundation is to promote,
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1 = """The mission of the Python Software Foundation is to promote, 
protect, and advance the Python programming language, 
and to support and facilitate the growth of a diverse and international"""

# %%
s1
# Out:
# 'The mission of the Python Software Foundation is to promote, \nprotect, and advance the Python programming language, \nand to support and facilitate the growth of a diverse and international'

# %%
date = "2003"

# %%
print(date)
# Out:
# 2003

# %%
date = "'3250'"

# %%
print (date)
# Out:
# '3250'

# %%
date = '"8272"'

# %%
print(date)
# Out:
# "8272"

# %%
name = "Anush"
education = "B.tech"
branch = "ECE"

# %%
print(name, education, branch)
# Out:
# Anush B.tech ECE

# %%
print("my name is", name, "my education is", education, "my department", branch)
# Out:
# my name is Anush my education is B.tech my department ECE

# %% [raw]
# %s, %d, %.f

# %%
"my name is %s, my education is %s, my department is %s"%(name, education, branch)
# Out:
# 'my name is Anush, my education is B.tech, my department is ECE'

# %%
age = 22
lang = 4.22

# %%
"my name is %s, my education is %s, my department is %s, my age is %d, my language is %.f"%(name, education, branch, age, lang)
# Out:
# 'my name is Anush, my education is B.tech, my department is ECE, my age is 22, my language is 4'

# %%
"my name is %s, my education is %s, my department is %s, my age is %d, my language is %.2f"%(name, education, branch, age, lang)
# Out:
# 'my name is Anush, my education is B.tech, my department is ECE, my age is 22, my language is 4.22'

# %%
"my name is {} my education is {} my department is {} my age is {} my language is {}".format(name, education, branch, age, lang)
# Out:
# 'my name is Anush my education is B.tech my department is ECE my age is 22 my language is 4.22'

# %%
f"my name is {name} my education is {education} my department is {branch} my age is {age} my language is {lang} "
# Out:
# 'my name is Anush my education is B.tech my department is ECE my age is 22 my language is 4.22 '

# %%
f"adjakhd {name}"
# Out:
# 'adjakhd Anush'

# %%
r''
# Out:
# ''

# %%
"file:///C:/Users/Dell/Downloads/REVALUATION%20SUPPLE%20WINTER%20-2024.pdf"
# Out:
# 'file:///C:/Users/Dell/Downloads/REVALUATION%20SUPPLE%20WINTER%20-2024.pdf'

# %%
print(name)
print(education)
print(branch)
# Out:
# Anush
# B.tech
# ECE

# %%
print(name, end = " ")
print(education, end = " ")
print(branch)
# Out:
# Anush B.tech ECE

# %%
var = "this is my first string variable"

# %%
var
# Out:
# 'this is my first string variable'

# %% [markdown]
# ## concat

# %%
var + name
# Out:
# 'this is my first string variableAnush'

# %%
var + " " + name + education
# Out:
# 'this is my first string variable AnushB.tech'

# %% [markdown]
# ## repeatation

# %%
name * 3
# Out:
# 'AnushAnushAnush'

# %%
var * 3
# Out:
# 'this is my first string variablethis is my first string variablethis is my first string variable'

# %% [markdown]
# ## indexing

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[4]
# Out:
# ' '

# %%
var[10]
# Out:
# ' '

# %%
var[8]
# Out:
# 'm'

# %%
var[5]
# Out:
# 'i'

# %%
var[-2]
# Out:
# 'l'

# %%
var[-1]
# Out:
# 'e'

# %% [markdown]
# ## Slicing

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[2:16]
# Out:
# 'is is my first'

# %%
var[3:10]
# Out:
# 's is my'

# %%
var[1:15:2]
# Out:
# 'hsi yfr'

# %%
var[1:]
# Out:
# 'his is my first string variable'

# %%
var[:10]
# Out:
# 'this is my'

# %%
var[::1]
# Out:
# 'this is my first string variable'

# %%
var[::-1]
# Out:
# 'elbairav gnirts tsrif ym si siht'

# %%
var[::-2]
# Out:
# 'ebia nrstrfy ish'

# %%
var[::1]
# Out:
# 'this is my first string variable'

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[2:10:-2]
# Out:
# ''

# %%
var[0:10:-1]
# Out:
# ''

# %%
var[20:5:-2]
# Out:
# 'it si ms'

# %% [markdown]
# ## mutation

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[5] = "I"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 var[5] = "I"
#
# TypeError: 'str' object does not support item assignment

# %%
"data" in subject
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 "data" in subject
#
# NameError: name 'subject' is not defined

# %%
"Data" in subject
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 "Data" in subject
#
# NameError: name 'subject' is not defined

# %%
s1
# Out:
# 'The mission of the Python Software Foundation is to promote, \nprotect, and advance the Python programming language, \nand to support and facilitate the growth of a diverse and international'

# %%
"skills" in s1
# Out:
# False

# %%
"skills" in s1
# Out:
# False

# %%
"data" is "DATA"
# Out:
# False

# %%
name is subject
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 name is subject
#
# NameError: name 'subject' is not defined

# %%
len(8272)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 len(8272)
#
# TypeError: object of type 'int' has no len()

# %%
4/1
# Out:
# 4.0

# %%
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %%
ds_lang = "python"

# %%
ds_lang
# Out:
# 'python'

# %% [markdown]
# ## Function

# %%
var
# Out:
# 'this is my first string variable'

# %%
type(var)
# Out:
# str

# %%
var.

# %%
l1 = []

# %%
l1.

# %%
l1.

# %%
t1 = ()

# %%
t1.

# %%
var
# Out:
# 'this is my first string variable'

# %%
var.upper()
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.lower()
# Out:
# 'this is my first string variable'

# %%
var = var.upper()

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.lower()
# Out:
# 'this is my first string variable'

# %%
var.capitalize()
# Out:
# 'This is my first string variable'

# %%
title = var.title()

# %%
title
# Out:
# 'This Is My First String Variable'

# %%
title.swapcase()
# Out:
# 'tHIS iS mY fIRST sTRING vARIABLE'

# %%
D = "My name is anush"

# %%
D.swapcase()
# Out:
# 'mY NAME IS ANUSH'

# %%
var.center(90," ")
# Out:
# '                             THIS IS MY FIRST STRING VARIABLE                             '

# %%
D.center(45," ")
# Out:
# '               My name is anush              '

# %%
s2 = "python3.11"

# %%
s2
# Out:
# 'python3.11'

# %%
s2.isalnum()
# Out:
# False

# %%
s2.isalpha()
# Out:
# False

# %%
name.isalnum()
# Out:
# True

# %%
s2.isalnum()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
a = "ANUSH"
b = "Amit"
c = "Python3.11"
d = "python3.11"
e = 14552
f = "anya"
g = " "

# %%
a.isalnum()
# Out:
# True

# %%
b.isalnum()
# Out:
# True

# %%
c.isalnum()
# Out:
# False

# %%
e.isalnum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 e.isalnum()
#
# AttributeError: 'int' object has no attribute 'isalnum'

# %%
a.isalpha()
# Out:
# True

# %%
b.isalpha()
# Out:
# True

# %%
c.isalpha()
# Out:
# False

# %%
g.isspace()
# Out:
# True

# %%
c.isspace()
# Out:
# False

# %%
f.islower()
# Out:
# True

# %%
a.islower()
# Out:
# False

# %%
a.isupper()
# Out:
# True

# %%
b.isupper()
# Out:
# False

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.startswith("THIS")
# Out:
# True

# %%
var.startswith("H")
# Out:
# False

# %%
var.startswith("IS")
# Out:
# False

# %%
var.endswith("LE")
# Out:
# True

# %%
var.startswith("TH")
# Out:
# True

# %%
var.endswith("ABL")
# Out:
# False

# %%
var.endswith("ABLE")
# Out:
# True

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.count("I")
# Out:
# 5

# %%
var.index("H")
# Out:
# 1

# %%
var.find("I")
# Out:
# 2

# %%
var.rfind("I")
# Out:
# 27

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var = var.lower()

# %%
var
# Out:
# 'this is my first string variable'

# %%
var.index("i", 7)
# Out:
# 12
