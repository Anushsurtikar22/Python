# %%
f  = open("test.txt", "w")

# %%
f.write("this is my first")
# Out:
# 16

# %%
f.close()

# %%
f = open("test.txt", "r")

# %%
f.read()
# Out:
# 'this is my first'

# %%
f.close()

# %%
f = open("test.txt", "r+")

# %%
f.read()
# Out:
# 'this is my first'

# %%
f.write(" new content added")
# Out:
# 18

# %%
f.close()

# %%
f  =open("test.txt", "w")

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f.write("UnsupportedOperation: not readable")
# Out:
# 34

# %%
f.close()

# %%
f = open("test.txt", "a")

# %%
f.write("   hello")
# Out:
# 8

# %%
f.close()

# %%
with open("test.txt", "r") as f:
    print(f.read())
    f.close()
# Out:
# UnsupportedOperation: not readable   hello

# %%
# %%writefile dmeo.txt
# hello this is python
# Out:
# Overwriting dmeo.txt

# %% [markdown]
# # import os

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.txt',
#  'dmeo.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Python'

# %%
os.chdir("C:\\Users\\Dell\\Downloads")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Downloads'

# %%
os.listdir()
# Out:
# ['00. python live terminal.html',
#  '01 Day.ipynb',
#  '01. core_python.md',
#  '01. Day-1.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '1. FIRST PYTHON PROGRAMS.txt',
#  '10 Day.ipynb',
#  '10 TH MARKSHEE.pdf',
#  '12 TH MARKSHEET.pdf',
#  '1st Sem Backlog Marksheet.jpeg',
#  '2. ODD EVEN PYTHON PROGRAMS.txt',
#  '3. SPECIAL STAR PATTERN CODE.txt',
#  '4. FUNCTION USED IN LIST.txt',
#  '5TH_(Electronics and Communication Engineering)_SUMM_SUPP 25.docx',
#  '8 th sem.pdf',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).docx',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).pdf',
#  'Aadhar card.jpeg',
#  'All Mark sheets.pdf',
#  'ALL MARKSHEET 6 SEM (1).docx',
#  'ALL MARKSHEET 6 SEM.docx',
#  'All Sem Marksheet (1).docx',
#  'All Sem Marksheet (2).docx',
#  'All Sem Marksheet.docx',
#  'Anaconda3-2025.12-2-Windows-x86_64.exe',
#  'Anush M1 result supply 1 sem.xlsx',
#  'Anush result 4 sem NT.xlsx',
#  'Anush Results.pdf',
#  'Anush Results_.pdf',
#  'Anush Resume.pdf',
#  'Anush Sign.jpg',
#  'Anush Surtikar (1).pdf',
#  'Anush Surtikar (2).pdf',
#  'Anush Surtikar.pdf',
#  'Anush_Resume (2).docx',
#  'Anush_Resume (3).docx',
#  'Anush_Sign.jpg',
#  'Attendance.pdf',
#  'bhadekarnama.pdf',
#  'Bonafide.pdf',
#  'Cast validity  (1).pdf',
#  'CASTE CERTIFICATE.jpeg',
#  'CASTE CERTIFICATE.pdf',
#  'Certificate.jpeg',
#  'CET.pdf',
#  'ChromeSetup.exe',
#  'Copilot_20260629_080642.png',
#  'Copilot_20260821_133015.png',
#  'Data Science & Analytics With AI.jpeg',
#  'Declaration.pdf',
#  'Dell_DC15250_121_RPL.exe',
#  'desktop.ini',
#  'Distance.pdf',
#  'dotnet-sdk-10.0.302-win-x64.exe',
#  'ECE_REGU_5TH SEM_WIN 24 (1).docx',
#  'ECE_REGU_5TH SEM_WIN 24.docx',
#  'ECE_REGU_5TH SEM_WIN 24.pdf',
#  'electric bill, ghar tax.pdf',
#  'English 60 Day.png',
#  'Git-2.55.0.4-64-bit.exe',
#  'home work (1).txt',
#  'home work.txt',
#  'IMG-20260628-WA0099.jpg.jpeg',
#  'Income.pdf',
#  'Intel-HID-Event-Filter-Driver_92FH5_WIN64_2.2.2.18_A04.EXE',
#  'Mahajyoti form.pdf',
#  'Marksheet 1 to 7 sem.pdf',
#  'Marksheet.jpeg',
#  'Marksheet.pdf',
#  'mysql-installer-community-8.0.45.0.msi',
#  'NATIONALITY & DOMICILE.pdf',
#  'newdir',
#  'Non-creamy layer.jpeg',
#  'Notarized Declaration.pdf',
#  'OneDriveSetup.exe',
#  'photo (3).jpg',
#  'Photo A (2).jpeg',
#  'Photo.jpeg',
#  'postgresql-18.6-1-windows-x64.exe',
#  'Print Application _ Dashboard - MBA 1.pdf',
#  'Print Application _ Dashboard - MBA.pdf',
#  'pycharm-2026.1.exe',
#  'python-3.11.7-amd64.exe',
#  'python-3.14.3-amd64.exe',
#  'python-manager-26.0.msix',
#  'Reciept Cum Acknowledgement _ Dashboard - MBA.pdf',
#  'RESUME.pdf',
#  'Sign.jpeg',
#  'Snapchat-1779174127.jpg.jpeg',
#  'Snapchat-1864508483.jpg.jpeg',
#  'Snapchat-1883077106.jpg.jpeg',
#  'Snapchat-261512890.jpg.jpeg',
#  'Suchita Resume One page.pdf',
#  'Suchita Resume.docx',
#  'Suchita Resume.pdf',
#  'SUCHITA.pdf',
#  'TC.pdf',
#  'VSCodeUserSetup-x64-1.109.5.exe',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM (1).jpeg',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.10.58 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.17 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.18 PM.jpeg',
#  'WhatsApp Image 2026-06-28 at 11.34.23 PM.jpeg',
#  '~$ Thesis.docx']

# %%
os.mkdir("newdir")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 os.mkdir("newdir")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'newdir'

# %%
os.listdir()
# Out:
# ['00. python live terminal.html',
#  '01 Day.ipynb',
#  '01. core_python.md',
#  '01. Day-1.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '1. FIRST PYTHON PROGRAMS.txt',
#  '10 Day.ipynb',
#  '10 TH MARKSHEE.pdf',
#  '12 TH MARKSHEET.pdf',
#  '1st Sem Backlog Marksheet.jpeg',
#  '2. ODD EVEN PYTHON PROGRAMS.txt',
#  '3. SPECIAL STAR PATTERN CODE.txt',
#  '4. FUNCTION USED IN LIST.txt',
#  '5TH_(Electronics and Communication Engineering)_SUMM_SUPP 25.docx',
#  '8 th sem.pdf',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).docx',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).pdf',
#  'Aadhar card.jpeg',
#  'All Mark sheets.pdf',
#  'ALL MARKSHEET 6 SEM (1).docx',
#  'ALL MARKSHEET 6 SEM.docx',
#  'All Sem Marksheet (1).docx',
#  'All Sem Marksheet (2).docx',
#  'All Sem Marksheet.docx',
#  'Anaconda3-2025.12-2-Windows-x86_64.exe',
#  'Anush M1 result supply 1 sem.xlsx',
#  'Anush result 4 sem NT.xlsx',
#  'Anush Results.pdf',
#  'Anush Results_.pdf',
#  'Anush Resume.pdf',
#  'Anush Sign.jpg',
#  'Anush Surtikar (1).pdf',
#  'Anush Surtikar (2).pdf',
#  'Anush Surtikar.pdf',
#  'Anush_Resume (2).docx',
#  'Anush_Resume (3).docx',
#  'Anush_Sign.jpg',
#  'Attendance.pdf',
#  'bhadekarnama.pdf',
#  'Bonafide.pdf',
#  'Cast validity  (1).pdf',
#  'CASTE CERTIFICATE.jpeg',
#  'CASTE CERTIFICATE.pdf',
#  'Certificate.jpeg',
#  'CET.pdf',
#  'ChromeSetup.exe',
#  'Copilot_20260629_080642.png',
#  'Copilot_20260821_133015.png',
#  'Data Science & Analytics With AI.jpeg',
#  'Declaration.pdf',
#  'Dell_DC15250_121_RPL.exe',
#  'desktop.ini',
#  'Distance.pdf',
#  'dotnet-sdk-10.0.302-win-x64.exe',
#  'ECE_REGU_5TH SEM_WIN 24 (1).docx',
#  'ECE_REGU_5TH SEM_WIN 24.docx',
#  'ECE_REGU_5TH SEM_WIN 24.pdf',
#  'electric bill, ghar tax.pdf',
#  'English 60 Day.png',
#  'Git-2.55.0.4-64-bit.exe',
#  'home work (1).txt',
#  'home work.txt',
#  'IMG-20260628-WA0099.jpg.jpeg',
#  'Income.pdf',
#  'Intel-HID-Event-Filter-Driver_92FH5_WIN64_2.2.2.18_A04.EXE',
#  'Mahajyoti form.pdf',
#  'Marksheet 1 to 7 sem.pdf',
#  'Marksheet.jpeg',
#  'Marksheet.pdf',
#  'mysql-installer-community-8.0.45.0.msi',
#  'NATIONALITY & DOMICILE.pdf',
#  'newdir',
#  'Non-creamy layer.jpeg',
#  'Notarized Declaration.pdf',
#  'OneDriveSetup.exe',
#  'photo (3).jpg',
#  'Photo A (2).jpeg',
#  'Photo.jpeg',
#  'postgresql-18.6-1-windows-x64.exe',
#  'Print Application _ Dashboard - MBA 1.pdf',
#  'Print Application _ Dashboard - MBA.pdf',
#  'pycharm-2026.1.exe',
#  'python-3.11.7-amd64.exe',
#  'python-3.14.3-amd64.exe',
#  'python-manager-26.0.msix',
#  'Reciept Cum Acknowledgement _ Dashboard - MBA.pdf',
#  'RESUME.pdf',
#  'Sign.jpeg',
#  'Snapchat-1779174127.jpg.jpeg',
#  'Snapchat-1864508483.jpg.jpeg',
#  'Snapchat-1883077106.jpg.jpeg',
#  'Snapchat-261512890.jpg.jpeg',
#  'Suchita Resume One page.pdf',
#  'Suchita Resume.docx',
#  'Suchita Resume.pdf',
#  'SUCHITA.pdf',
#  'TC.pdf',
#  'VSCodeUserSetup-x64-1.109.5.exe',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM (1).jpeg',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.10.58 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.17 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.18 PM.jpeg',
#  'WhatsApp Image 2026-06-28 at 11.34.23 PM.jpeg',
#  '~$ Thesis.docx']

# %%
os.chdir("C:\\Users\\Dell\\Python")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.txt',
#  'dmeo.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
# %%writefile demo.py
print("hello")
# Out:
# Writing demo.py

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.py',
#  'demo.txt',
#  'dmeo.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
os.remove("demo.py")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.txt',
#  'dmeo.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
os.chdir("C:\\Users\\Dell/Downloads")

# %%
os.listdir()
# Out:
# ['00. python live terminal.html',
#  '01 Day.ipynb',
#  '01. core_python.md',
#  '01. Day-1.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '1. FIRST PYTHON PROGRAMS.txt',
#  '10 Day.ipynb',
#  '10 TH MARKSHEE.pdf',
#  '12 TH MARKSHEET.pdf',
#  '1st Sem Backlog Marksheet.jpeg',
#  '2. ODD EVEN PYTHON PROGRAMS.txt',
#  '3. SPECIAL STAR PATTERN CODE.txt',
#  '4. FUNCTION USED IN LIST.txt',
#  '5TH_(Electronics and Communication Engineering)_SUMM_SUPP 25.docx',
#  '8 th sem.pdf',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).docx',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).pdf',
#  'Aadhar card.jpeg',
#  'All Mark sheets.pdf',
#  'ALL MARKSHEET 6 SEM (1).docx',
#  'ALL MARKSHEET 6 SEM.docx',
#  'All Sem Marksheet (1).docx',
#  'All Sem Marksheet (2).docx',
#  'All Sem Marksheet.docx',
#  'Anaconda3-2025.12-2-Windows-x86_64.exe',
#  'Anush M1 result supply 1 sem.xlsx',
#  'Anush result 4 sem NT.xlsx',
#  'Anush Results.pdf',
#  'Anush Results_.pdf',
#  'Anush Resume.pdf',
#  'Anush Sign.jpg',
#  'Anush Surtikar (1).pdf',
#  'Anush Surtikar (2).pdf',
#  'Anush Surtikar.pdf',
#  'Anush_Resume (2).docx',
#  'Anush_Resume (3).docx',
#  'Anush_Sign.jpg',
#  'Attendance.pdf',
#  'bhadekarnama.pdf',
#  'Bonafide.pdf',
#  'Cast validity  (1).pdf',
#  'CASTE CERTIFICATE.jpeg',
#  'CASTE CERTIFICATE.pdf',
#  'Certificate.jpeg',
#  'CET.pdf',
#  'ChromeSetup.exe',
#  'Copilot_20260629_080642.png',
#  'Copilot_20260821_133015.png',
#  'Data Science & Analytics With AI.jpeg',
#  'Declaration.pdf',
#  'Dell_DC15250_121_RPL.exe',
#  'desktop.ini',
#  'Distance.pdf',
#  'dotnet-sdk-10.0.302-win-x64.exe',
#  'ECE_REGU_5TH SEM_WIN 24 (1).docx',
#  'ECE_REGU_5TH SEM_WIN 24.docx',
#  'ECE_REGU_5TH SEM_WIN 24.pdf',
#  'electric bill, ghar tax.pdf',
#  'English 60 Day.png',
#  'Git-2.55.0.4-64-bit.exe',
#  'home work (1).txt',
#  'home work.txt',
#  'IMG-20260628-WA0099.jpg.jpeg',
#  'Income.pdf',
#  'Intel-HID-Event-Filter-Driver_92FH5_WIN64_2.2.2.18_A04.EXE',
#  'Mahajyoti form.pdf',
#  'Marksheet 1 to 7 sem.pdf',
#  'Marksheet.jpeg',
#  'Marksheet.pdf',
#  'mysql-installer-community-8.0.45.0.msi',
#  'NATIONALITY & DOMICILE.pdf',
#  'newdir',
#  'Non-creamy layer.jpeg',
#  'Notarized Declaration.pdf',
#  'OneDriveSetup.exe',
#  'photo (3).jpg',
#  'Photo A (2).jpeg',
#  'Photo.jpeg',
#  'postgresql-18.6-1-windows-x64.exe',
#  'Print Application _ Dashboard - MBA 1.pdf',
#  'Print Application _ Dashboard - MBA.pdf',
#  'pycharm-2026.1.exe',
#  'python-3.11.7-amd64.exe',
#  'python-3.14.3-amd64.exe',
#  'python-manager-26.0.msix',
#  'Reciept Cum Acknowledgement _ Dashboard - MBA.pdf',
#  'RESUME.pdf',
#  'Sign.jpeg',
#  'Snapchat-1779174127.jpg.jpeg',
#  'Snapchat-1864508483.jpg.jpeg',
#  'Snapchat-1883077106.jpg.jpeg',
#  'Snapchat-261512890.jpg.jpeg',
#  'Suchita Resume One page.pdf',
#  'Suchita Resume.docx',
#  'Suchita Resume.pdf',
#  'SUCHITA.pdf',
#  'TC.pdf',
#  'VSCodeUserSetup-x64-1.109.5.exe',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM (1).jpeg',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.10.58 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.17 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.18 PM.jpeg',
#  'WhatsApp Image 2026-06-28 at 11.34.23 PM.jpeg',
#  '~$ Thesis.docx']

# %%
os.rmdir("newdir")

# %%
os.listdir()
# Out:
# ['00. python live terminal.html',
#  '01 Day.ipynb',
#  '01. core_python.md',
#  '01. Day-1.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '1. FIRST PYTHON PROGRAMS.txt',
#  '10 Day.ipynb',
#  '10 TH MARKSHEE.pdf',
#  '12 TH MARKSHEET.pdf',
#  '1st Sem Backlog Marksheet.jpeg',
#  '2. ODD EVEN PYTHON PROGRAMS.txt',
#  '3. SPECIAL STAR PATTERN CODE.txt',
#  '4. FUNCTION USED IN LIST.txt',
#  '5TH_(Electronics and Communication Engineering)_SUMM_SUPP 25.docx',
#  '8 th sem.pdf',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).docx',
#  '8TH SEM MARKSHEET (PROVISIONAL) (2).pdf',
#  'Aadhar card.jpeg',
#  'All Mark sheets.pdf',
#  'ALL MARKSHEET 6 SEM (1).docx',
#  'ALL MARKSHEET 6 SEM.docx',
#  'All Sem Marksheet (1).docx',
#  'All Sem Marksheet (2).docx',
#  'All Sem Marksheet.docx',
#  'Anaconda3-2025.12-2-Windows-x86_64.exe',
#  'Anush M1 result supply 1 sem.xlsx',
#  'Anush result 4 sem NT.xlsx',
#  'Anush Results.pdf',
#  'Anush Results_.pdf',
#  'Anush Resume.pdf',
#  'Anush Sign.jpg',
#  'Anush Surtikar (1).pdf',
#  'Anush Surtikar (2).pdf',
#  'Anush Surtikar.pdf',
#  'Anush_Resume (2).docx',
#  'Anush_Resume (3).docx',
#  'Anush_Sign.jpg',
#  'Attendance.pdf',
#  'bhadekarnama.pdf',
#  'Bonafide.pdf',
#  'Cast validity  (1).pdf',
#  'CASTE CERTIFICATE.jpeg',
#  'CASTE CERTIFICATE.pdf',
#  'Certificate.jpeg',
#  'CET.pdf',
#  'ChromeSetup.exe',
#  'Copilot_20260629_080642.png',
#  'Copilot_20260821_133015.png',
#  'Data Science & Analytics With AI.jpeg',
#  'Declaration.pdf',
#  'Dell_DC15250_121_RPL.exe',
#  'desktop.ini',
#  'Distance.pdf',
#  'dotnet-sdk-10.0.302-win-x64.exe',
#  'ECE_REGU_5TH SEM_WIN 24 (1).docx',
#  'ECE_REGU_5TH SEM_WIN 24.docx',
#  'ECE_REGU_5TH SEM_WIN 24.pdf',
#  'electric bill, ghar tax.pdf',
#  'English 60 Day.png',
#  'Git-2.55.0.4-64-bit.exe',
#  'home work (1).txt',
#  'home work.txt',
#  'IMG-20260628-WA0099.jpg.jpeg',
#  'Income.pdf',
#  'Intel-HID-Event-Filter-Driver_92FH5_WIN64_2.2.2.18_A04.EXE',
#  'Mahajyoti form.pdf',
#  'Marksheet 1 to 7 sem.pdf',
#  'Marksheet.jpeg',
#  'Marksheet.pdf',
#  'mysql-installer-community-8.0.45.0.msi',
#  'NATIONALITY & DOMICILE.pdf',
#  'Non-creamy layer.jpeg',
#  'Notarized Declaration.pdf',
#  'OneDriveSetup.exe',
#  'photo (3).jpg',
#  'Photo A (2).jpeg',
#  'Photo.jpeg',
#  'postgresql-18.6-1-windows-x64.exe',
#  'Print Application _ Dashboard - MBA 1.pdf',
#  'Print Application _ Dashboard - MBA.pdf',
#  'pycharm-2026.1.exe',
#  'python-3.11.7-amd64.exe',
#  'python-3.14.3-amd64.exe',
#  'python-manager-26.0.msix',
#  'Reciept Cum Acknowledgement _ Dashboard - MBA.pdf',
#  'RESUME.pdf',
#  'Sign.jpeg',
#  'Snapchat-1779174127.jpg.jpeg',
#  'Snapchat-1864508483.jpg.jpeg',
#  'Snapchat-1883077106.jpg.jpeg',
#  'Snapchat-261512890.jpg.jpeg',
#  'Suchita Resume One page.pdf',
#  'Suchita Resume.docx',
#  'Suchita Resume.pdf',
#  'SUCHITA.pdf',
#  'TC.pdf',
#  'VSCodeUserSetup-x64-1.109.5.exe',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM (1).jpeg',
#  'WhatsApp Image 2026-03-07 at 6.00.13 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.10.58 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.17 PM.jpeg',
#  'WhatsApp Image 2026-03-07 at 6.40.18 PM.jpeg',
#  'WhatsApp Image 2026-06-28 at 11.34.23 PM.jpeg',
#  '~$ Thesis.docx']

# %%
os.chdir('C:\\Users\\Dell/Python')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Python'

# %%
#relative path

filepath = "demo.txt"
filepath = "Python/demo.txt"
filepath = 'C:\\Users\\Dell'

# %%
# absolute path - full path from root of the file system

filepath = 'C:\\Users\\Dell\\Downloads'

# %%
filepath1 = 'C:\\Users\\Dell/Downloads'
filepath2 = 'Python/demo.txt'

# %%
os.path.join(filepath1, filepath2)
# Out:
# 'C:\\Users\\Dell/Downloads\\Python/demo.txt'

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    with open(file_name, "w") as file:
        file.write(f"This is File {i}\n")

print("10 files created successfully!")
# Out:
# 10 files created successfully!

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    if os.path.exists(file_name):
        os.remove(file_name)
        print(f"{file_name} deleted.")
    else:
        print(f"{file_name} not found.")

print("Process completed.")
# Out:
# file_1.txt deleted.
# file_2.txt deleted.
# file_3.txt deleted.
# file_4.txt deleted.
# file_5.txt deleted.
# file_6.txt deleted.
# file_7.txt deleted.
# file_8.txt deleted.
# file_9.txt deleted.
# file_10.txt deleted.
# Process completed.

# %%
with open("student.txt", "w") as file:
    for i in range(1, 11):
        file.write(f"This is line {i}\n")

print("File created successfully.")
# Out:
# File created successfully.

# %%
students = ["Amit", "Rahul", "Priya", "Neha", "Rohit"]

with open("students.txt", "w") as file:
    for student in students:
        file.write(student + "\n")

print("Student names written successfully.")
# Out:
# Student names written successfully.

# %%
for i in range(1, 11):
    with open(f"file_{i}.txt", "w") as file:
        for j in range(1, 6):
            file.write(f"Line {j} of File {i}\n")

print("10 files created with 5 lines each.")
# Out:
# 10 files created with 5 lines each.

# %%
import os

file_name = "student.txt"

if os.path.exists(file_name):
    os.remove(file_name)
    print("File deleted successfully.")
else:
    print("File not found.")
# Out:
# File deleted successfully.

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.txt',
#  'dmeo.txt',
#  'file_1.txt',
#  'file_10.txt',
#  'file_2.txt',
#  'file_3.txt',
#  'file_4.txt',
#  'file_5.txt',
#  'file_6.txt',
#  'file_7.txt',
#  'file_8.txt',
#  'file_9.txt',
#  'students.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    with open(file_name, "w") as file:
        file.write(f"This is File {i}\n")

print("10 files created successfully!")
# Out:
# 10 files created successfully!

# %%
for i in range(1,11):
    file_name = f"file_{i}.txt"
    print(file_name)
# Out:
# file_1.txt
# file_2.txt
# file_3.txt
# file_4.txt
# file_5.txt
# file_6.txt
# file_7.txt
# file_8.txt
# file_9.txt
# file_10.txt

# %%
type(os.listdir())
# Out:
# list

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01 Day.ipynb',
#  '02 Day.ipynb',
#  '03 Day.ipynb',
#  '04 Day.ipynb',
#  '05 Day.ipynb',
#  '06 Day.ipynb',
#  '07 Day.ipynb',
#  '08 Day.ipynb',
#  '09 Day.ipynb',
#  '10 Day.ipynb',
#  '11 Day.ipynb',
#  'demo.txt',
#  'dmeo.txt',
#  'file_1.txt',
#  'file_10.txt',
#  'file_2.txt',
#  'file_3.txt',
#  'file_4.txt',
#  'file_5.txt',
#  'file_6.txt',
#  'file_7.txt',
#  'file_8.txt',
#  'file_9.txt',
#  'students.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb']

# %%
for i in os.listdir():
    if i == 'Untitled2.ipynb':
        os.remove(i)
