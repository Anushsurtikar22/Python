# %%
def add(num1, num2)-> int:
    """this is my first function
    which use to add two number
    argument will be intger"""
    return num1 + num2

# %%
add(5, 6)
# Out:
# 11

# %%
def printname()-> str:
    name = input()
    return name

# %%
print()

# %%
printname()
# Out:
#  Anush
# 'Anush'

# %% [markdown]
# ## OOPs

# %% [raw]
# class
# self
# __init__
# def
# public variable
# protected variable
# private variable
# override method
# inheritence
# polymorphism
# encapsulation
# super()
# mro()
# duck typing
# @staticmethod

# %%
class person:

    def __init__ (self, name, profession, dob ):
        self.name = name
        self.profession = profession
        self.dob = dob

# %%
obj = person ("rohit", "b'day", "2003")

# %%
obj.name
# Out:
# 'rohit'

# %%
obj.dob
# Out:
# '2003'

# %%
obj2 = person("Anush", "cricketer", "2010")

# %%
obj2.name
# Out:
# 'Anush'

# %%
obj.name
# Out:
# 'rohit'

# %%
class person:

    def __init__ (self, name, profession, dob):
        self.name = name
        self.profession = profession
        self.dob = dob

    def __init__ (self, name, profession):
        self.name = name
        self.profession = profession

    def __init__ (self, name, profession, dob, education):
        self.name = name
        self.profession = profession
        self.dob = dob
        self.education = education

# %%
obj = person ("Vishal", "trainer", "2019", "B.Tech")

# %%
obj.education
# Out:
# 'B.Tech'

# %%
class person:

    company = "KPIT"

    def __init__ (self, name, profession, dob, education):
        self.name = name
        self.profession = profession
        self.dob = dob
        self.education = education

# %%
obj = person ("Vivek", "Data Analyst", "2015", "B.tech")

# %%
obj.company
# Out:
# 'KPIT'

# %%
class person:

    company = "TCS"

    def __init__ (self, name, profession, dob, education):
        self.name = name
        self.profession = profession
        self.dob = dob
        self.education = education

    def age(self, current_year):
        return current_year - int(self.dob)

# %%
obj = person ("Amit", "Data scientist", "1991", "B.Tech")

# %%
obj.dob
# Out:
# '1991'

# %%
obj.age(2026)
# Out:
# 35

# %%
obj.company
# Out:
# 'TCS'

# %%
class person:

    company = "TCS"

    def __init__ (self, name, professional, dob, education):
        self.name = name
        self.professional = professional
        self.dob = dob
        self.education = education

    def age(self, current_year):
        return current_year - self.dob

    def company1 (self, new_company):
        self.new_company = new_company
        return new_company

# %%
obj = person("vikash", "trainer", 1990, "BE")

# %%
obj.company
# Out:
# 'TCS'

# %%
obj.company1("nifty")
# Out:
# 'nifty'

# %%
obj.dob
# Out:
# 1990

# %%
class PublicExample:
    def __init__ (self):
        self.public_var = "I'm public"   # Public attribute

    def public_method (self):  # Public method
        return "This is a public method"

# %%
obj = PublicExample()

# %%
obj.public_var
# Out:
# "I'm public"

# %%
obj.public_method()
# Out:
# 'This is a public method'

# %%
class ProtectedExample:

    _company = "TCS"

    def __init__ (self):
        self._protected_var = "I'm protected"  # Protected attribute

    def _protected_method (self):  # Protected method 
        return "This is a protected method"

    def access_protected (self):
        """Public method to access protected members"""
        return self._protected_var

# %%
obj = ProtectedExample()

# %%
obj._protected_method()
# Out:
# 'This is a protected method'

# %%
obj._company
# Out:
# 'TCS'

# %%
obj._protected_var
# Out:
# "I'm protected"

# %%
class PrivateExample:
    def __init__ (self):
        self.__private_var = "I'm private"  # Private attribute
        self.public_var = "I'm public"

    def __private_method(self):  # Private method 
        return "This is a private method"

    def access_private(self):
        """Public method to access private members"""
        return self.__private_var + " - " + self.__private_method()

# %%
obj = PrivateExample()

# %%
obj.access_private()
# Out:
# "I'm private - This is a private method"

# %%
obj._PrivateExample__private_method()
# Out:
# 'This is a private method'

# %%
obj._PrivateExample__private_var
# Out:
# "I'm private"

# %%
class Calculator:

    """hello word"""

    def __init__ (self, value) -> int:
        self._value = value

    def add(self, num):  # Instance method
        """Adds number to instance value"""
        self._value += num
        return self._value

    def get_value(self):  # Instance method
        """Returns current value"""
        return self._value

# %%
cal = Calculator(999)

# %%
cal.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 cal.value
#
# AttributeError: 'Calculator' object has no attribute 'value'

# %%
cal.add(5001)
# Out:
# 6000

# %%
cal.get_value()
# Out:
# 6000

# %%
cal.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 cal.value
#
# AttributeError: 'Calculator' object has no attribute 'value'

# %%
class MathUtils:
    @staticmethod
    def add (a,b):  # Static method
        """Adds two numbers"""
        return a + b

    @staticmethod
    def is_even (num):  # Static method
        """Checks if number is even"""
        return num % 2 == 0

    @staticmethod
    def factorial(n):  #static method
        """Calculates factorial"""
        if n <= 1:
            return 1
        return n * MathUtils.factorial(n - 1)

# %%
math = MathUtils()

# %%
math.factorial(6)
# Out:
# 720
