# %% [markdown]
# ## List

# %%
lis = []

# %%
type(lis)
# Out:
# list

# %%
l1 = ["red", 'pink', 'yellow', 'orange']

# %%
l2 = ['white', 'black', 'blue', 'purple', 'grey']

# %%
l3 = l1 + l2

# %%
l3
# Out:
# ['red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey']

# %%
l2 * 3
# Out:
# ['white',
#  'black',
#  'blue',
#  'purple',
#  'grey',
#  'white',
#  'black',
#  'blue',
#  'purple',
#  'grey',
#  'white',
#  'black',
#  'blue',
#  'purple',
#  'grey']

# %%
l3
# Out:
# ['red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey']

# %%
l3[3]
# Out:
# 'orange'

# %%
l3[-3]
# Out:
# 'blue'

# %%
l3[-1]
# Out:
# 'grey'

# %%
l3[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l3[9]
#
# IndexError: list index out of range

# %%
l3 [2:]
# Out:
# ['yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey']

# %%
l3[:15]
# Out:
# ['red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey']

# %%
l3[::-2]
# Out:
# ['grey', 'blue', 'white', 'yellow', 'red']

# %%
l3[5:1:-1]
# Out:
# ['black', 'white', 'orange', 'yellow']

# %%
l3 [2:8:-1]
# Out:
# []

# %%
l3 [2:8:1]
# Out:
# ['yellow', 'orange', 'white', 'black', 'blue', 'purple']

# %%
l3
# Out:
# ['red', 'pink', 'yellow', 'orange', 'white', 'black', 'blue', 'purple', 'grey']

# %%
l3 [2] = "skyblue"

# %%
l3
# Out:
# ['red',
#  'pink',
#  'skyblue',
#  'orange',
#  'white',
#  'black',
#  'blue',
#  'purple',
#  'grey']

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey']

# %%
l2.append(22)

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 22]

# %%
l2.append(18)

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 22, 18]

# %%
l2.append("pink")

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 22, 18, 'pink']

# %%
l2.extend(22)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l2.extend(22)
#
# TypeError: 'int' object is not iterable

# %%
l2.extend("22")

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 22, 18, 'pink', '2', '2']

# %%
l2.extend(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l2.extend(2)
#
# TypeError: 'int' object is not iterable

# %%
l1
# Out:
# ['red', 'pink', 'yellow', 'orange']

# %%
l2.extend(l1)

# %%
l2
# Out:
# ['white',
#  'black',
#  'blue',
#  'purple',
#  'grey',
#  22,
#  18,
#  'pink',
#  '2',
#  '2',
#  'red',
#  'pink',
#  'yellow',
#  'orange']

# %%
l2.pop()
# Out:
# 'yellow'

# %%
l2
# Out:
# ['white',
#  'black',
#  'blue',
#  'purple',
#  'grey',
#  22,
#  18,
#  'pink',
#  '2',
#  '2',
#  'red',
#  'pink']

# %%
l2.remove(22)

# %%
l2
# Out:
# ['white',
#  'black',
#  'blue',
#  'purple',
#  'grey',
#  18,
#  'pink',
#  '2',
#  '2',
#  'red',
#  'pink']

# %%
l2.remove("pink")

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 18, '2', '2', 'red', 'pink']

# %%
l2.remove("2")

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 18, '2', 'red', 'pink']

# %%
l4 = l2.copy()

# %%
l4
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 18, '2', 'red', 'pink']

# %%
l4.clear()

# %%
l4
# Out:
# []

# %%
l2
# Out:
# ['white', 'black', 'blue', 'purple', 'grey', 18, '2', 'red', 'pink']

# %%
l2[3]
# Out:
# 'purple'

# %%
l2.insert(1, "orange")

# %%
l2
# Out:
# ['white', 'orange', 'black', 'blue', 'purple', 'grey', 18, '2', 'red', 'pink']

# %%
l2.reverse()

# %%
l2
# Out:
# ['pink', 'red', '2', 18, 'grey', 'purple', 'blue', 'black', 'orange', 'white']

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l5 = [1,2,3,4,5,6,7,2,3,5]

# %%
l5.sort()

# %%
l5
# Out:
# [1, 2, 2, 3, 3, 4, 5, 5, 6, 7]

# %%
l1
# Out:
# ['red', 'pink', 'yellow', 'orange']

# %%
tuple(l1)
# Out:
# ('red', 'pink', 'yellow', 'orange')

# %% [markdown]
# ## Set

# %%
s1 = {1,2,3,4,5,6,1,2,34,}

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 6, 34}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.add(2.2)

# %%
s1
# Out:
# {1, 2, 2.2, 3, 4}

# %%
s1.update({5})

# %%
s1
# Out:
# {1, 2, 2.2, 3, 4, 5}

# %%
s1.update([7,8])

# %%
s1
# Out:
# {1, 2, 2.2, 3, 4, 5, 7, 8}

# %%
s1.pop()
# Out:
# 1

# %%
s1.pop()
# Out:
# 2

# %%
s1
# Out:
# {2.2, 3, 4, 5, 7, 8}

# %%
s1.remove(3)

# %%
s1
# Out:
# {2.2, 4, 5, 7, 8}

# %%
s1 = {1,2,3,4}
s2 = {3,4,5,6}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.difference_update(s2, "9,8")

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1
# Out:
# {1, 2}

# %%
s2.difference(s1)
# Out:
# {5, 6}

# %%
s1.intersection(s2)
# Out:
# {3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1 & s2
# Out:
# {3, 4}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {3, 4, 5, 6}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {3, 4}

# %%
s3 = {3,4,5,6,7}
s4 = {3,4}

# %%
s3.issubset(s4)
# Out:
# False

# %%
s4.issubset(s3)
# Out:
# True

# %%
s3.issuperset(s4)
# Out:
# True

# %%
s3
# Out:
# {3, 4, 5, 6, 7}

# %%
s5 = frozenset(s3)

# %%
s5
# Out:
# frozenset({3, 4, 5, 6, 7})

# %%
type(s5)
# Out:
# frozenset

# %%
s3
# Out:
# {3, 4, 5, 6, 7}

# %%
4 in s3
# Out:
# True

# %%
8 in s3
# Out:
# False

# %%
s3 is s4
# Out:
# False

# %%
s3 in s4
# Out:
# False
